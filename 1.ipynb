# %% [markdown]
# # Domain Analysis

# %% [raw]
# ----> About Dataset <-------
# The Raisin Dataset is a commonly used dataset in the field of data science and machine learning, particularly for classification tasks. It consists of various attributes extracted from images of two different types of raisins: Kecimen and Besni.

# %% [raw]
# > Type: Image classification dataset (features are extracted from the images)
# > Classes: 2 (Kecimen and Besni)
# > Number of Instances: 900 samples (450 samples for each class)
# > Number of Features: 7 features extracted from the images

# %% [raw]
# Features:
# > Area: The number of pixels within the boundaries of the raisin.
# > Perimeter: The length of the boundary around the raisin.
# > MajorAxisLength: The longest diameter of the raisin.
# > MinorAxisLength: The shortest diameter of the raisin.
# > Eccentricity: The ratio of the distance between the focus of the ellipse and its major axis length (shape descriptor).
# > ConvexArea: The area of the convex hull containing the raisin.
# > Extent: The ratio of the area of the raisin to the area of the bounding box.

# %% [markdown]
# ## Import Libreries

# %%
## importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#%matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('raisin1.csv')

# %%
data
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# ...

# %% [markdown]
# ## Basic Operations

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             900 non-null    int64
#  1   MajorAxisLength  900 non-null    float64
#  2   MinorAxisLength  900 non-null    float64
#  3   Eccentricity     900 non-null    float64
#  4   ConvexArea       900 non-null    int64
#  5   Extent           900 non-null    float64
#  6   Perimeter        900 non-null    float64
#  7   Class            900 non-null    object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 56.4+ KB

# %%
data.describe()
# Out:
#                 Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count     900.000000       900.000000       900.000000    900.000000
# mean    87804.127778       430.929950       254.488133      0.781542
# std     39002.111390       116.035121        49.988902      0.090318
# min     25387.000000       225.629541       143.710872      0.348730
# 25%     59348.000000       345.442898       219.111126      0.741766
# 50%     78902.000000       407.803951       247.848409      0.798846
# 75%    105028.250000       494.187014       279.888575      0.842571
# max    235047.000000       997.291941       492.275279      0.962124
#
#           ConvexArea      Extent    Perimeter
# count     900.000000  900.000000   900.000000
# mean    91186.090000    0.699508  1165.906636
# std     40769.290132    0.053468   273.764315
# min     26139.000000    0.379856   619.074000
# 25%     61513.250000    0.670869   966.410750
# 50%     81651.000000    0.707367  1119.509000
# ...

# %%
data.head()
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter    Class
# 0  0.758651   1184.040  Kecimen
# 1  0.684130   1121.786  Kecimen
# 2  0.637613   1208.575  Kecimen
# 3  0.699599    844.162  Kecimen
# 4  0.792772   1073.251  Kecimen

# %%
data.tail()
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter  Class
# 895  0.668793   1129.072  Besni
# 896  0.636476   1214.252  Besni
# 897  0.741099   1292.828  Besni
# 898  0.658798   1258.548  Besni
# 899  0.632020   1272.862  Besni

# %%
data.isnull()
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    False            False            False         False       False
# 1    False            False            False         False       False
# 2    False            False            False         False       False
# 3    False            False            False         False       False
# 4    False            False            False         False       False
# ..     ...              ...              ...           ...         ...
# 895  False            False            False         False       False
# 896  False            False            False         False       False
# 897  False            False            False         False       False
# 898  False            False            False         False       False
# 899  False            False            False         False       False
#
#      Extent  Perimeter  Class
# 0     False      False  False
# 1     False      False  False
# ...

# %%
data.dtypes
# Out:
# Area                 int64
# MajorAxisLength    float64
# MinorAxisLength    float64
# Eccentricity       float64
# ConvexArea           int64
# Extent             float64
# Perimeter          float64
# Class               object
# dtype: object

# %%
sns.countplot(x='Class',data=data)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# ## Kecimen and Besni's values are same

# %%
data.MinorAxisLength.value_counts()
# Out:
# 253.291155    1
# 308.000127    1
# 304.156469    1
# 300.635686    1
# 217.561151    1
#              ..
# 258.892006    1
# 234.697936    1
# 210.611522    1
# 191.169862    1
# 215.271976    1
# Name: MinorAxisLength, Length: 900, dtype: int64

# %%
for column in data:
    print(column)
# Out:
# Area
# MajorAxisLength
# MinorAxisLength
# Eccentricity
# ConvexArea
# Extent
# Perimeter
# Class

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in data:
    ax=plt.subplot(3,3,plotnumber)
    sns.histplot(data[column])
    plt.xlabel(column,fontsize=20)
    plt.ylabel('Count',fontsize=20)
    plotnumber+=1
plt.tight_layout()   

> Most Demanding perimeters between 1000 and 1300
> Eccentricity are high in range of 90.09
> Convexarea are high in range of 5000 to 100000
>

# %%
sns.countplot(x="Area",hue='Extent',data=data)
plt.show()

# %%
sns.histplot(x='Area',hue='Class',data=data)
# Out:
# <Axes: xlabel='Area', ylabel='Count'>

# %% [markdown]
# ### The most area have 5000 and 100000 are high in range

# %%
sns.relplot(x='Area',y='MinorAxisLength',hue='Class',data=data)
plt.show()

# %%
sns.relplot(x='Extent',y='ConvexArea',hue='Class',data=data)
plt.show()

# %% [markdown]
# ### Convex area and Extent values are gathered between 0.7 and 0.8 are high in range

# %%
sns.relplot(x='Eccentricity',y='ConvexArea',hue='Class',data=data)
plt.show()

# %%
plt.figure(figsize=(15,10))
for i,col in enumerate(data.iloc[:, :-1],1):
    plt.subplot(4,3,i)
    plt.title(f"Distribution of {col} Data")
    sns.histplot(data[col],kde=True)
    plt.tight_layout()
    plt.plot()

# %% [raw]
# > Distribution of area high in 5000 and 100000
# > Ditribution of MajorAxisLength are high in 300 to 400
# > Ditribution of MinorAxisLength are high in range of 240 and 60
# > Eccentricity Data  are 0.8
# > Convex area couting in 5000 to 100000
# > Extent in the area of 0.7
# > Primeters having are 1000 1500
# > Both perimeter having the 1000

# %%
sns.pairplot(data, hue= "Class");

# %%
def detect_and_plot_outliers(df, target_column):
    features = data.columns.difference([target_column])
    
    # Create subplots
    plt.figure(figsize=(20, 15))
    
    for i, col in enumerate(features, 1):
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 2.5 * IQR
        upper_bound = Q3 + 2.5 * IQR
        
        # Detect outliers
        outliers = df[(df[col] < lower_bound) | (data[col] > upper_bound)]
        
        # Plotting
        plt.subplot(4, 3, i)
        sns.boxplot(x=target_column, y=col, data=data)
        plt.scatter(outliers[target_column], outliers[col], color='red', label='Outliers')
        plt.title(f"{col} with Outliers")
        plt.legend()
        plt.tight_layout()
    
    plt.show()

detect_and_plot_outliers(data, 'Class')

# %%
def plot_target_correlation_heatmap(df, target_variable):
    df_numeric = df.select_dtypes(include=[np.number])
    df_corr_target = df_numeric.corr()
    
    plt.figure(figsize=(2, 7))
    sns.heatmap(df_corr_target[[target_variable]], annot=True, vmin=-1, vmax=1, cmap="Blues")
    plt.title(f'Correlation with {target_variable}')
    plt.show()
plot_target_correlation_heatmap(data, 'Area')

# %%
sns.heatmap(data.corr(), cmap='Blues', annot= True)
# Out:
# <Axes: >

# %%
def color_correlation1(val):
    if val >= 0.6 and val < 0.99999 or val <= -0.6 and val > -0.99999:
        color = 'red'
    elif val < 0.6 and val >= 0.3 or val > -0.6 and val <= -0.3:
        color = 'blue'
    elif val == 1:
        color = 'green'    
    else:
        color = 'black'
    return 'color: %s' % color

numeric_df = data.select_dtypes(include=[np.number])

numeric_df.corr().style.applymap(color_correlation1)
# Out:
# <style type="text/css">
# #T_439c7_row0_col0, #T_439c7_row1_col1, #T_439c7_row2_col2, #T_439c7_row3_col3, #T_439c7_row4_col4, #T_439c7_row5_col5, #T_439c7_row6_col6 {
#   color: green;
# }
# #T_439c7_row0_col1, #T_439c7_row0_col2, #T_439c7_row0_col4, #T_439c7_row0_col6, #T_439c7_row1_col0, #T_439c7_row1_col2, #T_439c7_row1_col4, #T_439c7_row1_col6, #T_439c7_row2_col0, #T_439c7_row2_col1, #T_439c7_row2_col4, #T_439c7_row2_col6, #T_439c7_row4_col0, #T_439c7_row4_col1, #T_439c7_row4_col2, #T_439c7_row4_col6, #T_439c7_row6_col0, #T_439c7_row6_col1, #T_439c7_row6_col2, #T_439c7_row6_col4 {
#   color: red;
# }
# #T_439c7_row0_col3, #T_439c7_row1_col3, #T_439c7_row3_col0, #T_439c7_row3_col1, #T_439c7_row3_col4, #T_439c7_row3_col5, #T_439c7_row3_col6, #T_439c7_row4_col3, #T_439c7_row5_col3, #T_439c7_row6_col3 {
#   color: blue;
# }
# ...

# %% [markdown]
# # Models
